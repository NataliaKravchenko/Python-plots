# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Nat\Downloads\housing (1).data",
                      sep='\\s+')

df.columns = ['crime_rate','<25,000 sq.ft','non-ret_buz','riv_tract','nox_conc','num_rooms','age_built<1940',
              'dist_empl','acc_highway','prop_tax','pup-teach_ratio','black','low_pop','price']


fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(df.corr(), annot=True, cmap='winter')
ax.set_xticklabels(df.columns, rotation=90)
ax.set_yticklabels(df.columns)
# Out:
# [Text(0, 0.5, 'crime_rate'),
#  Text(0, 1.5, '<25,000 sq.ft'),
#  Text(0, 2.5, 'non-ret_buz'),
#  Text(0, 3.5, 'riv_tract'),
#  Text(0, 4.5, 'nox_conc'),
#  Text(0, 5.5, 'num_rooms'),
#  Text(0, 6.5, 'age_built<1940'),
#  Text(0, 7.5, 'dist_empl'),
#  Text(0, 8.5, 'acc_highway'),
#  Text(0, 9.5, 'prop_tax'),
#  Text(0, 10.5, 'pup-teach_ratio'),
#  Text(0, 11.5, 'black'),
#  Text(0, 12.5, 'low_pop'),
#  Text(0, 13.5, 'price')]
